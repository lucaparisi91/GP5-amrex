# %%
import numpy as np
import scipy as sp
import matplotlib.pylab as plt
from gp import io
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 import scipy as sp
#       3 import matplotlib.pylab as plt
# ----> 4 from gp import io
#
# ImportError: cannot import name 'io' from 'gp' (/home/luca/source/GP5/amrex_gp/python/gp/__init__.py)

# %%
# %matplotlib notebook
y=io.load("../build/gaussianL.hdf5")
domain=[ [-1,1],[-0.5,0.5],[-0.5,0.5]]
deltax= [  (domain[d][1] - domain[d][0] )/y.shape[d]   for d in range(3)  ]
X,Y,Z=io.generateGrid(y.shape, domain)
R=np.sqrt(X**2 + Y**2 + Z**2)
sigma=0.05
alpha=1/(2*sigma**2)
yd2=np.exp(-alpha*R**2)*(-2*alpha)*(3 - 2*alpha*R**2)
yG=np.exp(-alpha*R**2)
plt.plot( R.flatten() , y.flatten() )
plt.plot( R.flatten() ,yd2.flatten() , "--" )
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# /home/luca/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
kx=np.fft.fftfreq( y.shape[0]) * 2* np.pi / deltax[0]

KX,KY,KZ=np.meshgrid(kx,kx,kx,indexing="ij")
K=np.sqrt(KX**2 + KY**2 + KZ**2)
# Out:
# 2.7857380999792376e-11

# %%
K2=KX**2 + KY**2 + KZ**2

# %%
K22=np.real(io.load("../build/K2.hdf5"))
np.max(K22-K2)
# Out:
# 8.731149137020111e-11
